# %%
import pandas as pd
from datasets import load_dataset_builder, load_dataset, DatasetDict

SEED = 42

# %%
df_medquad = pd.read_csv("../data/medquad_cleaned.csv")
df_medquad.columns.tolist()
# Out:
# ['doc_id', 'focus', 'source', 'qid', 'question', 'answer', 'qtype']

# %%
df_medquad.shape
# Out:
# (16407, 7)
